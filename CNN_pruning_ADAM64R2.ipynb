# %% [markdown]
# # ADAM - 64 - R2

# %% [markdown]
# Imports

# %%
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras import callbacks
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Input, Conv2D, MaxPooling2D, UpSampling2D, Activation, Dropout, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import fashion_mnist, cifar10

import matplotlib.pyplot as plt
import tempfile
# limit GPU memory to stop kernel crashw
#gpu_devices = tf.config.experimental.list_physical_devices('GPU')
#tf.config.experimental.set_memory_growth(gpu_devices[0], True)
#
layers = tf.keras.layers
import numpy as np
print(tf.__version__)
#print (gpu_devices)

from tensorflow.keras.callbacks import EarlyStopping
early_stopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='auto')
import tensorflow_model_optimization as tfmot
# Out:
# 2.3.1

# %%
# Loading Fashion MNIST datset

(train_X, train_Y), (val_X, val_Y) = fashion_mnist.load_data()

# %%
# converting all the pixel values from range(0 to 255) to range(0,1)
train_X = train_X/255.
val_X = val_X/255.

#converting the Image data into values of pixels, i.e. - image of dimension 28 X 28 to single row of 784 pixels(28x28 = 784).
print("Dimension of training data before reshaping",train_X.shape)
train_X = train_X.reshape(-1, 784)
val_X = val_X.reshape(-1, 784)
print("Dimension of training data after reshaping",train_X.shape)
print("Dimension of validation data after reshaping",val_X.shape)
# Out:
# Dimension of training data before reshaping (60000, 28, 28)
# Dimension of training data after reshaping (60000, 784)
# Dimension of validation data after reshaping (10000, 784)

# %% [markdown]
# ### 4) CNN on CIFAR10 dataset

# %%
# CNN

def prepare_cifar10_data(subtract_pixel_mean = True):

    #load cifar10 data and returns the data in the format required

    # The data, split between train and test sets:
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    # Normalize data.
    x_train = x_train.astype('float32') / 255
    x_test = x_test.astype('float32') / 255
    num_classes=10
    # If subtract pixel mean is enabled (Subtracting pixel mean improves accuracy)
    if subtract_pixel_mean:
        x_train_mean = np.mean(x_train, axis=0)
        x_train -= x_train_mean
        x_test -= x_train_mean

    # Convert class vectors to binary class matrices.
    y_train = tensorflow.keras.utils.to_categorical(y_train, num_classes)
    y_test = tensorflow.keras.utils.to_categorical(y_test, num_classes)

    return (x_train, y_train),(x_test,y_test)


def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

def CNN(input_shape, num_classes=10):

    #CNN model for CIFAR10

    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=input_shape))
    model.add(Activation('relu'))
    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(num_classes))
    model.add(Activation('softmax'))

    model.compile(loss='mean_squared_error',
                  optimizer=Adam(learning_rate=lr_schedule(0)),
                  metrics=['accuracy'])
    #Categorical crossentropy loss function used

    init = model.get_weights()

    return model, init


def get_gzipped_model_size(file):
    # Returns size of gzipped model, in bytes.
    # Not used here. Used if we wanted to compare compression of models
    import os
    import zipfile

    _, zipped_file = tempfile.mkstemp('.zip')
    with zipfile.ZipFile(zipped_file, 'w', compression=zipfile.ZIP_DEFLATED) as f:
        f.write(file)

    return os.path.getsize(zipped_file)



##Functions for pruning CNN - same as the pruning functions of autoencoders, but for CNN####

def cnn_pruning(model, train_X, train_Y, test_X, test_Y, batch_size, epochs, final_sparsity):

    # Function pruning 5% of weights of model over epochs epochs and returning the error on test data
    # and size of compressed file (not used here)

    prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude
    # Compute end step to finish pruning after epochs epochs.

    num_images = train_X.shape[0]
    end_step = np.ceil(num_images / batch_size).astype(np.int32) * epochs
    print(f'cnn_pruning with final_sparsity: {final_sparsity}')

    # Define model for pruning.
    pruning_params = {
          'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.,
                                                               final_sparsity=final_sparsity,
                                                               begin_step=0,
                                                               end_step=end_step)
    }

    model_pruning = prune_low_magnitude(to_prune=model, **pruning_params)
    # `prune_low_magnitude` requires a recompile.
    model_pruning.compile(optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7), loss='mean_squared_error')
    # Model callbacks
    callbacks = [
      tfmot.sparsity.keras.UpdatePruningStep()
    ]
    # Fitting data
    model_pruning.fit(train_X, train_Y,
                          batch_size=batch_size,
                          validation_data=(test_X,test_Y),
                          epochs=epochs,
                          callbacks=callbacks)
    # Export the model
    model_for_export = tfmot.sparsity.keras.strip_pruning(model_pruning)
    _, pruned_keras_file = tempfile.mkstemp('.h5')
    #save_model(model_for_export, pruned_keras_file, include_optimizer=False)
    model_for_export.save(pruned_keras_file, include_optimizer=False)
    print(f'Pruned model saved: {pruned_keras_file}')

    # to predict the reconstructed images for the original images...
    pred_pruning = model_pruning.predict(test_X)
    cce = tf.keras.losses.MeanSquaredError()
    error_prun=cce(test_Y, pred_pruning).numpy()
    size_pruned_file=get_gzipped_model_size(pruned_keras_file)

    return error_prun, size_pruned_file


def cnn_prune_all(model, train_X, train_Y, test_X, test_Y, batch_size, epochs):

    #####NOTE#####
    # There is a bug in tfmot.sparsity.keras.PolynomialDecay#
    # When I try to pass final_sparsity=final_sparsity it triggers an error
    # When we input a number manually it works
    # Otherwise clearly I would have done a loop
    #########

    # Pruning between 5% and 95% of weights in order to make plot

    err_prun_list=[]
    size_prun_file_list=[]

    for i in range(5, 96, 5):
        error_prun, size_pruned_file = cnn_pruning(model=model, train_X=train_X, train_Y=train_Y, test_X=test_X,
                                                   test_Y=test_Y, batch_size=batch_size,epochs=epochs, final_sparsity=i / 100.0)
        err_prun_list.append(error_prun)
        size_prun_file_list.append(size_pruned_file)

    return err_prun_list, size_prun_file_list

# %%
num_classes=10
#Loading CIFAR10 data (10 classes)
(x_train,y_train),(x_test,y_test) = prepare_cifar10_data(subtract_pixel_mean=True)

# Making CNN model
cnn_cifar, init = CNN(input_shape=x_train.shape[1:])
# Training CNN model 50 epochs
cnn_cifar.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test), callbacks=[early_stopper])

#calculating Categorical crossentropy loss on test data
pred6 = cnn_cifar.predict(x_test)
cce = tf.keras.losses.MeanSquaredError()

error6=cce(y_test, pred6).numpy()
print(error6)
error6_list=np.ones(19)*error6

#Pruning CNN and getting errors per percentage of synapses pruned

err_prun6_list, size_prun6_file_list = cnn_prune_all(model=cnn_cifar, train_X=x_train, train_Y=y_train,
                                                    test_X=x_test, test_Y=y_test, batch_size=128, epochs=5)
# Out:
# Learning rate:  0.001
# Epoch 1/50
# 391/391 [==============================] - 209s 533ms/step - loss: 0.0648 - accuracy: 0.4825 - val_loss: 0.0524 - val_accuracy: 0.6036
# Epoch 2/50
# 391/391 [==============================] - 179s 459ms/step - loss: 0.0468 - accuracy: 0.6512 - val_loss: 0.0444 - val_accuracy: 0.6733
# Epoch 3/50
# 391/391 [==============================] - 145s 371ms/step - loss: 0.0381 - accuracy: 0.7238 - val_loss: 0.0385 - val_accuracy: 0.7188
# Epoch 4/50
# 391/391 [==============================] - 157s 402ms/step - loss: 0.0317 - accuracy: 0.7744 - val_loss: 0.0372 - val_accuracy: 0.7322
# Epoch 5/50
# 391/391 [==============================] - 146s 373ms/step - loss: 0.0259 - accuracy: 0.8189 - val_loss: 0.0367 - val_accuracy: 0.7362
# Epoch 6/50
# 391/391 [==============================] - 118s 302ms/step - loss: 0.0210 - accuracy: 0.8576 - val_loss: 0.0345 - val_accuracy: 0.7565
# Epoch 7/50
# 391/391 [==============================] - 126s 322ms/step - loss: 0.0167 - accuracy: 0.8899 - val_loss: 0.0365 - val_accuracy: 0.7514
# Epoch 8/50
# 391/391 [==============================] - 129s 329ms/step - loss: 0.0132 - accuracy: 0.9147 - val_loss: 0.0371 - val_accuracy: 0.7513
# Epoch 9/50
# 391/391 [==============================] - 116s 296ms/step - loss: 0.0108 - accuracy: 0.9314 - val_loss: 0.0373 - val_accuracy: 0.7570
# Epoch 10/50
# 391/391 [==============================] - 91s 233ms/step - loss: 0.0087 - accuracy: 0.9458 - val_loss: 0.0382 - val_accuracy: 0.7532
# Epoch 11/50
# 391/391 [==============================] - 88s 225ms/step - loss: 0.0081 - accuracy: 0.9502 - val_loss: 0.0394 - val_accuracy: 0.7523
# Epoch 12/50
# 391/391 [==============================] - 81s 208ms/step - loss: 0.0072 - accuracy: 0.9556 - val_loss: 0.0399 - val_accuracy: 0.7490
# Epoch 13/50
# 391/391 [==============================] - 87s 222ms/step - loss: 0.0065 - accuracy: 0.9605 - val_loss: 0.0404 - val_accuracy: 0.7501
# Epoch 14/50
# 391/391 [==============================] - 85s 218ms/step - loss: 0.0062 - accuracy: 0.9625 - val_loss: 0.0397 - val_accuracy: 0.7568
# Epoch 15/50
# 391/391 [==============================] - 85s 218ms/step - loss: 0.0062 - accuracy: 0.9625 - val_loss: 0.0423 - val_accuracy: 0.7414
# Epoch 16/50
# 391/391 [==============================] - 85s 218ms/step - loss: 0.0061 - accuracy: 0.9629 - val_loss: 0.0406 - val_accuracy: 0.7502
# Epoch 00016: early stopping
# 0.040592853
# cnn_pruning with final_sparsity: 0.05
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/sparsity/keras/pruning_wrapper.py:200: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# Epoch 1/5
# 391/391 [==============================] - 72s 185ms/step - loss: 0.0058 - val_loss: 0.0416
# Epoch 2/5
# 391/391 [==============================] - 57s 146ms/step - loss: 0.0052 - val_loss: 0.0428
# Epoch 3/5
# 391/391 [==============================] - 54s 139ms/step - loss: 0.0053 - val_loss: 0.0418
# Epoch 4/5
# 391/391 [==============================] - 54s 139ms/step - loss: 0.0051 - val_loss: 0.0418
# Epoch 5/5
# 391/391 [==============================] - 54s 139ms/step - loss: 0.0049 - val_loss: 0.0432
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpujt4ic4f.h5
# cnn_pruning with final_sparsity: 0.1
# Epoch 1/5
# 391/391 [==============================] - 55s 142ms/step - loss: 0.0052 - val_loss: 0.0448
# Epoch 2/5
# 391/391 [==============================] - 58s 149ms/step - loss: 0.0049 - val_loss: 0.0428
# Epoch 3/5
# 391/391 [==============================] - 58s 149ms/step - loss: 0.0045 - val_loss: 0.0447
# Epoch 4/5
# 391/391 [==============================] - 59s 150ms/step - loss: 0.0044 - val_loss: 0.0441
# Epoch 5/5
# 391/391 [==============================] - 59s 151ms/step - loss: 0.0046 - val_loss: 0.0441
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp6za1itpr.h5
# cnn_pruning with final_sparsity: 0.15
# Epoch 1/5
# 391/391 [==============================] - 57s 147ms/step - loss: 0.0049 - val_loss: 0.0450
# Epoch 2/5
# 391/391 [==============================] - 59s 151ms/step - loss: 0.0046 - val_loss: 0.0449
# Epoch 3/5
# 391/391 [==============================] - 59s 150ms/step - loss: 0.0040 - val_loss: 0.0436
# Epoch 4/5
# 391/391 [==============================] - 59s 150ms/step - loss: 0.0039 - val_loss: 0.0449
# Epoch 5/5
# 391/391 [==============================] - 59s 151ms/step - loss: 0.0044 - val_loss: 0.0443
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp56vx3t5e.h5
# cnn_pruning with final_sparsity: 0.2
# Epoch 1/5
# 391/391 [==============================] - 59s 151ms/step - loss: 0.0047 - val_loss: 0.0442
# Epoch 2/5
# 391/391 [==============================] - 59s 151ms/step - loss: 0.0043 - val_loss: 0.0443
# Epoch 3/5
# 391/391 [==============================] - 59s 152ms/step - loss: 0.0043 - val_loss: 0.0457
# Epoch 4/5
# 391/391 [==============================] - 59s 151ms/step - loss: 0.0040 - val_loss: 0.0473
# Epoch 5/5
# 391/391 [==============================] - 59s 151ms/step - loss: 0.0038 - val_loss: 0.0461
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmprmlz6wzw.h5
# cnn_pruning with final_sparsity: 0.25
# Epoch 1/5
# 391/391 [==============================] - 61s 156ms/step - loss: 0.0047 - val_loss: 0.0486
# Epoch 2/5
# 391/391 [==============================] - 61s 155ms/step - loss: 0.0045 - val_loss: 0.0455
# Epoch 3/5
# 391/391 [==============================] - 60s 154ms/step - loss: 0.0040 - val_loss: 0.0455
# Epoch 4/5
# 391/391 [==============================] - 60s 154ms/step - loss: 0.0041 - val_loss: 0.0467
# Epoch 5/5
# 391/391 [==============================] - 60s 154ms/step - loss: 0.0039 - val_loss: 0.0457
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpe10aud3g.h5
# cnn_pruning with final_sparsity: 0.3
# Epoch 1/5
# 391/391 [==============================] - 58s 148ms/step - loss: 0.0046 - val_loss: 0.0459
# Epoch 2/5
# 391/391 [==============================] - 58s 147ms/step - loss: 0.0045 - val_loss: 0.0455
# Epoch 3/5
# 391/391 [==============================] - 58s 148ms/step - loss: 0.0041 - val_loss: 0.0462
# Epoch 4/5
# 391/391 [==============================] - 58s 147ms/step - loss: 0.0040 - val_loss: 0.0454
# Epoch 5/5
# 391/391 [==============================] - 58s 148ms/step - loss: 0.0034 - val_loss: 0.0465
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpw3078he7.h5
# cnn_pruning with final_sparsity: 0.35
# Epoch 1/5
# 391/391 [==============================] - 57s 146ms/step - loss: 0.0050 - val_loss: 0.0469
# Epoch 2/5
# 391/391 [==============================] - 68s 175ms/step - loss: 0.0039 - val_loss: 0.0468
# Epoch 3/5
# 391/391 [==============================] - 59s 151ms/step - loss: 0.0037 - val_loss: 0.0479
# Epoch 4/5
# 391/391 [==============================] - 58s 149ms/step - loss: 0.0041 - val_loss: 0.0456
# Epoch 5/5
# 391/391 [==============================] - 58s 148ms/step - loss: 0.0039 - val_loss: 0.0475
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpmf530k73.h5
# cnn_pruning with final_sparsity: 0.4
# Epoch 1/5
# 391/391 [==============================] - 57s 147ms/step - loss: 0.0049 - val_loss: 0.0483
# Epoch 2/5
# 391/391 [==============================] - 58s 149ms/step - loss: 0.0046 - val_loss: 0.0478
# Epoch 3/5
# 391/391 [==============================] - 59s 150ms/step - loss: 0.0040 - val_loss: 0.0474
# Epoch 4/5
# 391/391 [==============================] - 59s 150ms/step - loss: 0.0040 - val_loss: 0.0474
# Epoch 5/5
# 391/391 [==============================] - 58s 149ms/step - loss: 0.0039 - val_loss: 0.0465
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp3ugchs6y.h5
# cnn_pruning with final_sparsity: 0.45
# Epoch 1/5
# 391/391 [==============================] - 59s 151ms/step - loss: 0.0050 - val_loss: 0.0485
# Epoch 2/5
# 391/391 [==============================] - 59s 151ms/step - loss: 0.0047 - val_loss: 0.0479
# Epoch 3/5
# 391/391 [==============================] - 59s 150ms/step - loss: 0.0038 - val_loss: 0.0482
# Epoch 4/5
# 391/391 [==============================] - 59s 151ms/step - loss: 0.0040 - val_loss: 0.0490
# Epoch 5/5
# 391/391 [==============================] - 59s 151ms/step - loss: 0.0037 - val_loss: 0.0493
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpphl85bv4.h5
# cnn_pruning with final_sparsity: 0.5
# Epoch 1/5
# 391/391 [==============================] - 55s 140ms/step - loss: 0.0055 - val_loss: 0.0508
# Epoch 2/5
# 391/391 [==============================] - 57s 145ms/step - loss: 0.0050 - val_loss: 0.0482
# Epoch 3/5
# 391/391 [==============================] - 57s 146ms/step - loss: 0.0038 - val_loss: 0.0486
# Epoch 4/5
# 391/391 [==============================] - 57s 145ms/step - loss: 0.0039 - val_loss: 0.0485
# Epoch 5/5
# 391/391 [==============================] - 57s 146ms/step - loss: 0.0039 - val_loss: 0.0484
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp0rvr4lzf.h5
# cnn_pruning with final_sparsity: 0.55
# Epoch 1/5
# 391/391 [==============================] - 58s 148ms/step - loss: 0.0053 - val_loss: 0.0485
# Epoch 2/5
# 391/391 [==============================] - 58s 149ms/step - loss: 0.0048 - val_loss: 0.0487
# Epoch 3/5
# 391/391 [==============================] - 58s 149ms/step - loss: 0.0037 - val_loss: 0.0479
# Epoch 4/5
# 391/391 [==============================] - 58s 149ms/step - loss: 0.0038 - val_loss: 0.0470
# Epoch 5/5
# 391/391 [==============================] - 58s 148ms/step - loss: 0.0038 - val_loss: 0.0479
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpg99df47y.h5
# cnn_pruning with final_sparsity: 0.6
# Epoch 1/5
# 391/391 [==============================] - 57s 146ms/step - loss: 0.0055 - val_loss: 0.0503
# Epoch 2/5
# 391/391 [==============================] - 58s 148ms/step - loss: 0.0045 - val_loss: 0.0498
# Epoch 3/5
# 391/391 [==============================] - 58s 148ms/step - loss: 0.0037 - val_loss: 0.0478
# Epoch 4/5
# 391/391 [==============================] - 58s 148ms/step - loss: 0.0041 - val_loss: 0.0487
# Epoch 5/5
# 391/391 [==============================] - 58s 148ms/step - loss: 0.0039 - val_loss: 0.0486
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpdb2_70r7.h5
# cnn_pruning with final_sparsity: 0.65
# Epoch 1/5
# 391/391 [==============================] - 58s 149ms/step - loss: 0.0056 - val_loss: 0.0502
# Epoch 2/5
# 391/391 [==============================] - 58s 149ms/step - loss: 0.0049 - val_loss: 0.0481
# Epoch 3/5
# 391/391 [==============================] - 58s 149ms/step - loss: 0.0035 - val_loss: 0.0472
# Epoch 4/5
# 391/391 [==============================] - 58s 149ms/step - loss: 0.0038 - val_loss: 0.0483
# Epoch 5/5
# 391/391 [==============================] - 59s 150ms/step - loss: 0.0037 - val_loss: 0.0474
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpm56avbo3.h5
# cnn_pruning with final_sparsity: 0.7
# Epoch 1/5
# 391/391 [==============================] - 54s 139ms/step - loss: 0.0063 - val_loss: 0.0486
# Epoch 2/5
# 391/391 [==============================] - 54s 138ms/step - loss: 0.0044 - val_loss: 0.0485
# Epoch 3/5
# 391/391 [==============================] - 54s 139ms/step - loss: 0.0033 - val_loss: 0.0476
# Epoch 4/5
# 391/391 [==============================] - 54s 139ms/step - loss: 0.0039 - val_loss: 0.0480
# Epoch 5/5
# 391/391 [==============================] - 55s 140ms/step - loss: 0.0041 - val_loss: 0.0473
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmps85jpexo.h5
# cnn_pruning with final_sparsity: 0.75
# Epoch 1/5
# 391/391 [==============================] - 57s 145ms/step - loss: 0.0055 - val_loss: 0.0488
# Epoch 2/5
# 391/391 [==============================] - 57s 147ms/step - loss: 0.0044 - val_loss: 0.0469
# Epoch 3/5
# 391/391 [==============================] - 58s 147ms/step - loss: 0.0031 - val_loss: 0.0467
# Epoch 4/5
# 391/391 [==============================] - 58s 148ms/step - loss: 0.0040 - val_loss: 0.0477
# Epoch 5/5
# 391/391 [==============================] - 58s 148ms/step - loss: 0.0044 - val_loss: 0.0463
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmppufdh4xy.h5
# cnn_pruning with final_sparsity: 0.8
# Epoch 1/5
# 391/391 [==============================] - 56s 144ms/step - loss: 0.0055 - val_loss: 0.0477
# Epoch 2/5
# 391/391 [==============================] - 57s 146ms/step - loss: 0.0038 - val_loss: 0.0462
# Epoch 3/5
# 391/391 [==============================] - 58s 148ms/step - loss: 0.0029 - val_loss: 0.0457
# Epoch 4/5
# 391/391 [==============================] - 58s 147ms/step - loss: 0.0050 - val_loss: 0.0462
# Epoch 5/5
# 391/391 [==============================] - 57s 147ms/step - loss: 0.0056 - val_loss: 0.0445
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpk720tcc6.h5
# cnn_pruning with final_sparsity: 0.85
# Epoch 1/5
# 391/391 [==============================] - 58s 149ms/step - loss: 0.0057 - val_loss: 0.0454
# Epoch 2/5
# 391/391 [==============================] - 58s 149ms/step - loss: 0.0034 - val_loss: 0.0441
# Epoch 3/5
# 391/391 [==============================] - 58s 148ms/step - loss: 0.0027 - val_loss: 0.0442
# Epoch 4/5
# 391/391 [==============================] - 58s 149ms/step - loss: 0.0063 - val_loss: 0.0450
# Epoch 5/5
# 391/391 [==============================] - 59s 150ms/step - loss: 0.0080 - val_loss: 0.0431
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp2n6daeg5.h5
# cnn_pruning with final_sparsity: 0.9
# Epoch 1/5
# 391/391 [==============================] - 55s 141ms/step - loss: 0.0067 - val_loss: 0.0433
# Epoch 2/5
# 391/391 [==============================] - 57s 146ms/step - loss: 0.0032 - val_loss: 0.0430
# Epoch 3/5
# 391/391 [==============================] - 57s 147ms/step - loss: 0.0024 - val_loss: 0.0423
# Epoch 4/5
# 391/391 [==============================] - 57s 147ms/step - loss: 0.0105 - val_loss: 0.0433
# Epoch 5/5
# 391/391 [==============================] - 58s 148ms/step - loss: 0.0152 - val_loss: 0.0418
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpaieg2guu.h5
# cnn_pruning with final_sparsity: 0.95
# Epoch 1/5
# 391/391 [==============================] - 58s 149ms/step - loss: 0.0108 - val_loss: 0.0409
# Epoch 2/5
# 391/391 [==============================] - 58s 149ms/step - loss: 0.0041 - val_loss: 0.0402
# Epoch 3/5
# 391/391 [==============================] - 59s 150ms/step - loss: 0.0033 - val_loss: 0.0416
# Epoch 4/5
# 391/391 [==============================] - 59s 150ms/step - loss: 0.0220 - val_loss: 0.0478
# Epoch 5/5
# 391/391 [==============================] - 59s 150ms/step - loss: 0.0380 - val_loss: 0.0426
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpfpx5d2vw.h5

# %%
synapse_deletion=np.arange(0.05,1.,0.05)


plt.plot(synapse_deletion,err_prun6_list)
plt.plot(synapse_deletion,error6_list)
plt.title("CNN, Categorical Cross Entropy Loss as a function of synapse deletion \n CNN trained on 50 epochs \n + pruning over 5 epochs \n CIFAR10")
plt.xlabel("Synapse percentage deletion")
plt.ylabel("Categorical Cross Entropy Loss")
plt.show()

# %% [markdown]
# ### Observations: Contrary to Autoencoder, pruning up to 80% of weights does not help performance, but pruning between 80% and 95% of weights helps performance on test data
