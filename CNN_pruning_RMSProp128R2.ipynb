# %% [markdown]
# # RMSprop - 128 - R2

# %% [markdown]
# Imports

# %%
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras import callbacks
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import Dense, Input, Conv2D, MaxPooling2D, UpSampling2D, Activation, Dropout, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import fashion_mnist, cifar10

import matplotlib.pyplot as plt
import tempfile
# limit GPU memory to stop kernel crashw
#gpu_devices = tf.config.experimental.list_physical_devices('GPU')
#tf.config.experimental.set_memory_growth(gpu_devices[0], True)
#
layers = tf.keras.layers
import numpy as np
print(tf.__version__)
#print (gpu_devices)

from tensorflow.keras.callbacks import EarlyStopping
early_stopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='auto')
import tensorflow_model_optimization as tfmot
# Out:
# 2.3.1

# %%
# Loading Fashion MNIST datset

(train_X, train_Y), (val_X, val_Y) = fashion_mnist.load_data()

# %%
# converting all the pixel values from range(0 to 255) to range(0,1)
train_X = train_X/255.
val_X = val_X/255.

#converting the Image data into values of pixels, i.e. - image of dimension 28 X 28 to single row of 784 pixels(28x28 = 784).
print("Dimension of training data before reshaping",train_X.shape)
train_X = train_X.reshape(-1, 784)
val_X = val_X.reshape(-1, 784)
print("Dimension of training data after reshaping",train_X.shape)
print("Dimension of validation data after reshaping",val_X.shape)
# Out:
# Dimension of training data before reshaping (60000, 28, 28)
# Dimension of training data after reshaping (60000, 784)
# Dimension of validation data after reshaping (10000, 784)

# %% [markdown]
# ### 4) CNN on CIFAR10 dataset

# %%
# CNN

def prepare_cifar10_data(subtract_pixel_mean = True):

    #load cifar10 data and returns the data in the format required

    # The data, split between train and test sets:
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    # Normalize data.
    x_train = x_train.astype('float32') / 255
    x_test = x_test.astype('float32') / 255
    num_classes=10
    # If subtract pixel mean is enabled (Subtracting pixel mean improves accuracy)
    if subtract_pixel_mean:
        x_train_mean = np.mean(x_train, axis=0)
        x_train -= x_train_mean
        x_test -= x_train_mean

    # Convert class vectors to binary class matrices.
    y_train = tensorflow.keras.utils.to_categorical(y_train, num_classes)
    y_test = tensorflow.keras.utils.to_categorical(y_test, num_classes)

    return (x_train, y_train),(x_test,y_test)


def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

def CNN(input_shape, num_classes=10):

    #CNN model for CIFAR10

    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=input_shape))
    model.add(Activation('relu'))
    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(128, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(num_classes))
    model.add(Activation('softmax'))

    model.compile(loss='mean_squared_error',
                  optimizer=RMSprop(learning_rate=lr_schedule(0)),
                  metrics=['accuracy'])
    #Categorical crossentropy loss function used

    init = model.get_weights()

    return model, init


def get_gzipped_model_size(file):
    # Returns size of gzipped model, in bytes.
    # Not used here. Used if we wanted to compare compression of models
    import os
    import zipfile

    _, zipped_file = tempfile.mkstemp('.zip')
    with zipfile.ZipFile(zipped_file, 'w', compression=zipfile.ZIP_DEFLATED) as f:
        f.write(file)

    return os.path.getsize(zipped_file)



##Functions for pruning CNN - same as the pruning functions of autoencoders, but for CNN####

def cnn_pruning(model, train_X, train_Y, test_X, test_Y, batch_size, epochs, final_sparsity):

    # Function pruning 5% of weights of model over epochs epochs and returning the error on test data
    # and size of compressed file (not used here)

    prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude
    # Compute end step to finish pruning after epochs epochs.

    num_images = train_X.shape[0]
    end_step = np.ceil(num_images / batch_size).astype(np.int32) * epochs
    print(f'cnn_pruning with final_sparsity: {final_sparsity}')

    # Define model for pruning.
    pruning_params = {
          'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.,
                                                               final_sparsity=final_sparsity,
                                                               begin_step=0,
                                                               end_step=end_step)
    }

    model_pruning = prune_low_magnitude(to_prune=model, **pruning_params)
    # `prune_low_magnitude` requires a recompile.
    model_pruning.compile(optimizer=RMSprop(lr=0.001, epsilon=1e-7), loss='mean_squared_error')
    # Model callbacks
    callbacks = [
      tfmot.sparsity.keras.UpdatePruningStep()
    ]
    # Fitting data
    model_pruning.fit(train_X, train_Y,
                          batch_size=batch_size,
                          validation_data=(test_X,test_Y),
                          epochs=epochs,
                          callbacks=callbacks)
    # Export the model
    model_for_export = tfmot.sparsity.keras.strip_pruning(model_pruning)
    _, pruned_keras_file = tempfile.mkstemp('.h5')
    #save_model(model_for_export, pruned_keras_file, include_optimizer=False)
    model_for_export.save(pruned_keras_file, include_optimizer=False)
    print(f'Pruned model saved: {pruned_keras_file}')

    # to predict the reconstructed images for the original images...
    pred_pruning = model_pruning.predict(test_X)
    cce = tf.keras.losses.MeanSquaredError()
    error_prun=cce(test_Y, pred_pruning).numpy()
    size_pruned_file=get_gzipped_model_size(pruned_keras_file)

    return error_prun, size_pruned_file


def cnn_prune_all(model, train_X, train_Y, test_X, test_Y, batch_size, epochs):

    #####NOTE#####
    # There is a bug in tfmot.sparsity.keras.PolynomialDecay#
    # When I try to pass final_sparsity=final_sparsity it triggers an error
    # When we input a number manually it works
    # Otherwise clearly I would have done a loop
    #########

    # Pruning between 5% and 95% of weights in order to make plot

    err_prun_list=[]
    size_prun_file_list=[]

    for i in range(5, 96, 5):
        error_prun, size_pruned_file = cnn_pruning(model=model, train_X=train_X, train_Y=train_Y, test_X=test_X,
                                                   test_Y=test_Y, batch_size=batch_size,epochs=epochs, final_sparsity=i / 100.0)
        err_prun_list.append(error_prun)
        size_prun_file_list.append(size_pruned_file)

    return err_prun_list, size_prun_file_list

# %%
num_classes=10
#Loading CIFAR10 data (10 classes)
(x_train,y_train),(x_test,y_test) = prepare_cifar10_data(subtract_pixel_mean=True)

# Making CNN model
cnn_cifar, init = CNN(input_shape=x_train.shape[1:])
# Training CNN model 50 epochs
cnn_cifar.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test), callbacks=[early_stopper])

#calculating Categorical crossentropy loss on test data
pred6 = cnn_cifar.predict(x_test)
cce = tf.keras.losses.MeanSquaredError()

error6=cce(y_test, pred6).numpy()
print(error6)
error6_list=np.ones(19)*error6

#Pruning CNN and getting errors per percentage of synapses pruned

err_prun6_list, size_prun6_file_list =cnn_prune_all(model=cnn_cifar, train_X=x_train, train_Y=y_train,
                                                    test_X=x_test, test_Y=y_test, batch_size=128, epochs=5)
# Out:
# Learning rate:  0.001
# Epoch 1/50
# 391/391 [==============================] - 396s 1s/step - loss: 0.0747 - accuracy: 0.3695 - val_loss: 0.0738 - val_accuracy: 0.3979
# Epoch 2/50
# 391/391 [==============================] - 389s 995ms/step - loss: 0.0581 - accuracy: 0.5465 - val_loss: 0.0551 - val_accuracy: 0.5778
# Epoch 3/50
# 391/391 [==============================] - 352s 901ms/step - loss: 0.0485 - accuracy: 0.6332 - val_loss: 0.0474 - val_accuracy: 0.6442
# Epoch 4/50
# 391/391 [==============================] - 349s 892ms/step - loss: 0.0415 - accuracy: 0.6944 - val_loss: 0.0501 - val_accuracy: 0.6260
# Epoch 5/50
# 391/391 [==============================] - 329s 842ms/step - loss: 0.0359 - accuracy: 0.7378 - val_loss: 0.0410 - val_accuracy: 0.7030
# Epoch 6/50
# 391/391 [==============================] - 316s 808ms/step - loss: 0.0317 - accuracy: 0.7738 - val_loss: 0.0374 - val_accuracy: 0.7353
# Epoch 7/50
# 391/391 [==============================] - 314s 804ms/step - loss: 0.0278 - accuracy: 0.8030 - val_loss: 0.0365 - val_accuracy: 0.7395
# Epoch 8/50
# 391/391 [==============================] - 309s 789ms/step - loss: 0.0248 - accuracy: 0.8285 - val_loss: 0.0367 - val_accuracy: 0.7448
# Epoch 9/50
# 391/391 [==============================] - 298s 763ms/step - loss: 0.0221 - accuracy: 0.8471 - val_loss: 0.0376 - val_accuracy: 0.7378
# Epoch 10/50
# 391/391 [==============================] - 314s 802ms/step - loss: 0.0194 - accuracy: 0.8677 - val_loss: 0.0363 - val_accuracy: 0.7507
# Epoch 11/50
# 391/391 [==============================] - 296s 757ms/step - loss: 0.0173 - accuracy: 0.8838 - val_loss: 0.0351 - val_accuracy: 0.7607
# Epoch 12/50
# 391/391 [==============================] - 312s 797ms/step - loss: 0.0156 - accuracy: 0.8969 - val_loss: 0.0372 - val_accuracy: 0.7578
# Epoch 13/50
# 391/391 [==============================] - 312s 797ms/step - loss: 0.0139 - accuracy: 0.9086 - val_loss: 0.0360 - val_accuracy: 0.7640
# Epoch 14/50
# 391/391 [==============================] - 282s 721ms/step - loss: 0.0126 - accuracy: 0.9174 - val_loss: 0.0367 - val_accuracy: 0.7657
# Epoch 15/50
# 391/391 [==============================] - 278s 711ms/step - loss: 0.0118 - accuracy: 0.9239 - val_loss: 0.0346 - val_accuracy: 0.7784
# Epoch 16/50
# 391/391 [==============================] - 292s 746ms/step - loss: 0.0108 - accuracy: 0.9307 - val_loss: 0.0397 - val_accuracy: 0.7523
# Epoch 17/50
# 391/391 [==============================] - 305s 780ms/step - loss: 0.0106 - accuracy: 0.9323 - val_loss: 0.0387 - val_accuracy: 0.7582
# Epoch 18/50
# 391/391 [==============================] - 298s 763ms/step - loss: 0.0098 - accuracy: 0.9385 - val_loss: 0.0373 - val_accuracy: 0.7725
# Epoch 19/50
# 391/391 [==============================] - 281s 720ms/step - loss: 0.0096 - accuracy: 0.9406 - val_loss: 0.0403 - val_accuracy: 0.7578
# Epoch 20/50
# 391/391 [==============================] - 291s 745ms/step - loss: 0.0093 - accuracy: 0.9419 - val_loss: 0.0394 - val_accuracy: 0.7670
# Epoch 21/50
# 391/391 [==============================] - 291s 743ms/step - loss: 0.0090 - accuracy: 0.9438 - val_loss: 0.0393 - val_accuracy: 0.7689
# Epoch 22/50
# 391/391 [==============================] - 295s 755ms/step - loss: 0.0093 - accuracy: 0.9430 - val_loss: 0.0390 - val_accuracy: 0.7714
# Epoch 23/50
# 391/391 [==============================] - 293s 749ms/step - loss: 0.0091 - accuracy: 0.9448 - val_loss: 0.0400 - val_accuracy: 0.7694
# Epoch 24/50
# 391/391 [==============================] - 293s 750ms/step - loss: 0.0090 - accuracy: 0.9459 - val_loss: 0.0404 - val_accuracy: 0.7672
# Epoch 25/50
# 391/391 [==============================] - 288s 736ms/step - loss: 0.0093 - accuracy: 0.9443 - val_loss: 0.0406 - val_accuracy: 0.7710
# Epoch 00025: early stopping
# 0.04056751
# cnn_pruning with final_sparsity: 0.05
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/sparsity/keras/pruning_wrapper.py:200: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# Epoch 1/5
# 391/391 [==============================] - 298s 763ms/step - loss: 0.0098 - val_loss: 0.0426
# Epoch 2/5
# 391/391 [==============================] - 296s 757ms/step - loss: 0.0094 - val_loss: 0.0421
# Epoch 3/5
# 391/391 [==============================] - 281s 720ms/step - loss: 0.0089 - val_loss: 0.0431
# Epoch 4/5
# 391/391 [==============================] - 296s 756ms/step - loss: 0.0091 - val_loss: 0.0463
# Epoch 5/5
# 391/391 [==============================] - 293s 748ms/step - loss: 0.0098 - val_loss: 0.0414
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpwpv670es.h5
# cnn_pruning with final_sparsity: 0.1
# Epoch 1/5
# 391/391 [==============================] - 304s 778ms/step - loss: 0.0112 - val_loss: 0.0444
# Epoch 2/5
# 391/391 [==============================] - 300s 768ms/step - loss: 0.0113 - val_loss: 0.0432
# Epoch 3/5
# 391/391 [==============================] - 281s 717ms/step - loss: 0.0111 - val_loss: 0.0464
# Epoch 4/5
# 391/391 [==============================] - 295s 755ms/step - loss: 0.0112 - val_loss: 0.0456
# Epoch 5/5
# 391/391 [==============================] - 308s 787ms/step - loss: 0.0122 - val_loss: 0.0493
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpln3uo128.h5
# cnn_pruning with final_sparsity: 0.15
# Epoch 1/5
# 391/391 [==============================] - 323s 827ms/step - loss: 0.0159 - val_loss: 0.0463
# Epoch 2/5
# 391/391 [==============================] - 292s 746ms/step - loss: 0.0163 - val_loss: 0.0516
# Epoch 3/5
# 391/391 [==============================] - 269s 687ms/step - loss: 0.0174 - val_loss: 0.0468
# Epoch 4/5
# 391/391 [==============================] - 285s 730ms/step - loss: 0.0183 - val_loss: 0.0537
# Epoch 5/5
# 391/391 [==============================] - 309s 790ms/step - loss: 0.0198 - val_loss: 0.0512
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpxxppzko6.h5
# cnn_pruning with final_sparsity: 0.2
# Epoch 1/5
# 391/391 [==============================] - 301s 769ms/step - loss: 0.0241 - val_loss: 0.0522
# Epoch 2/5
# 391/391 [==============================] - 285s 729ms/step - loss: 0.0251 - val_loss: 0.0622
# Epoch 3/5
# 391/391 [==============================] - 275s 704ms/step - loss: 0.0287 - val_loss: 0.0522
# Epoch 4/5
# 391/391 [==============================] - 295s 755ms/step - loss: 0.0292 - val_loss: 0.0538
# Epoch 5/5
# 391/391 [==============================] - 308s 788ms/step - loss: 0.0304 - val_loss: 0.0505
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp0zuwwp3q.h5
# cnn_pruning with final_sparsity: 0.25
# Epoch 1/5
# 391/391 [==============================] - 301s 771ms/step - loss: 0.0455 - val_loss: 0.0575
# Epoch 2/5
# 391/391 [==============================] - 289s 739ms/step - loss: 0.0468 - val_loss: 0.0605
# Epoch 3/5
# 391/391 [==============================] - 271s 693ms/step - loss: 0.0455 - val_loss: 0.0579
# Epoch 4/5
# 391/391 [==============================] - 300s 768ms/step - loss: 0.0486 - val_loss: 0.0611
# Epoch 5/5
# 391/391 [==============================] - 305s 780ms/step - loss: 0.0482 - val_loss: 0.0628
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpyscm7gnh.h5
# cnn_pruning with final_sparsity: 0.3
# Epoch 1/5
# 391/391 [==============================] - 284s 726ms/step - loss: 0.0700 - val_loss: 0.0747
# Epoch 2/5
# 391/391 [==============================] - 280s 717ms/step - loss: 0.0711 - val_loss: 0.0906
# Epoch 3/5
# 391/391 [==============================] - 280s 717ms/step - loss: 0.0634 - val_loss: 0.0770
# Epoch 4/5
# 391/391 [==============================] - 308s 788ms/step - loss: 0.0796 - val_loss: 0.0850
# Epoch 5/5
# 391/391 [==============================] - 308s 788ms/step - loss: 0.0734 - val_loss: 0.0757
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpgyubs_c3.h5
# cnn_pruning with final_sparsity: 0.35
# Epoch 1/5
# 391/391 [==============================] - 290s 742ms/step - loss: 0.0865 - val_loss: 0.1006
# Epoch 2/5
# 391/391 [==============================] - 243s 622ms/step - loss: 0.0775 - val_loss: 0.0839
# Epoch 3/5
# 391/391 [==============================] - 233s 595ms/step - loss: 0.0919 - val_loss: 0.1025
# Epoch 4/5
# 391/391 [==============================] - 256s 656ms/step - loss: 0.0959 - val_loss: 0.0978
# Epoch 5/5
# 391/391 [==============================] - 264s 675ms/step - loss: 0.0869 - val_loss: 0.1058
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp6r0ojm68.h5
# cnn_pruning with final_sparsity: 0.4
# Epoch 1/5
# 391/391 [==============================] - 253s 647ms/step - loss: 0.1237 - val_loss: 0.1236
# Epoch 2/5
# 391/391 [==============================] - 229s 587ms/step - loss: 0.1145 - val_loss: 0.1240
# Epoch 3/5
# 391/391 [==============================] - 245s 626ms/step - loss: 0.1547 - val_loss: 0.1191
# Epoch 4/5
# 391/391 [==============================] - 261s 668ms/step - loss: 0.1351 - val_loss: 0.1233
# Epoch 5/5
# 391/391 [==============================] - 263s 672ms/step - loss: 0.1007 - val_loss: 0.1095
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpp3k04bm0.h5
# cnn_pruning with final_sparsity: 0.45
# Epoch 1/5
# 391/391 [==============================] - 244s 623ms/step - loss: 0.1168 - val_loss: 0.1430
# Epoch 2/5
# 391/391 [==============================] - 240s 613ms/step - loss: 0.1152 - val_loss: 0.1344
# Epoch 3/5
# 391/391 [==============================] - 265s 677ms/step - loss: 0.1076 - val_loss: 0.1209
# Epoch 4/5
# 391/391 [==============================] - 277s 708ms/step - loss: 0.1180 - val_loss: 0.1030
# Epoch 5/5
# 391/391 [==============================] - 288s 737ms/step - loss: 0.1212 - val_loss: 0.1195
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpz9y663v8.h5
# cnn_pruning with final_sparsity: 0.5
# Epoch 1/5
# 391/391 [==============================] - 264s 676ms/step - loss: 0.1468 - val_loss: 0.1155
# Epoch 2/5
# 391/391 [==============================] - 267s 684ms/step - loss: 0.1499 - val_loss: 0.1095
# Epoch 3/5
# 391/391 [==============================] - 281s 717ms/step - loss: 0.1131 - val_loss: 0.0987
# Epoch 4/5
# 391/391 [==============================] - 280s 717ms/step - loss: 0.1235 - val_loss: 0.1318
# Epoch 5/5
# 391/391 [==============================] - 262s 671ms/step - loss: 0.1379 - val_loss: 0.1200
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpcnygnmh4.h5
# cnn_pruning with final_sparsity: 0.55
# Epoch 1/5
# 391/391 [==============================] - 241s 617ms/step - loss: 0.1656 - val_loss: 0.1795
# Epoch 2/5
# 391/391 [==============================] - 255s 653ms/step - loss: 0.1778 - val_loss: 0.1781
# Epoch 3/5
# 391/391 [==============================] - 258s 660ms/step - loss: 0.1788 - val_loss: 0.1701
# Epoch 4/5
# 391/391 [==============================] - 270s 689ms/step - loss: 0.1642 - val_loss: 0.1698
# Epoch 5/5
# 391/391 [==============================] - 285s 729ms/step - loss: 0.1608 - val_loss: 0.1451
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpvad2oceu.h5
# cnn_pruning with final_sparsity: 0.6
# Epoch 1/5
# 391/391 [==============================] - 271s 693ms/step - loss: 0.1673 - val_loss: 0.1742
# Epoch 2/5
# 391/391 [==============================] - 286s 731ms/step - loss: 0.1784 - val_loss: 0.1782
# Epoch 3/5
# 391/391 [==============================] - 272s 695ms/step - loss: 0.1683 - val_loss: 0.1529
# Epoch 4/5
# 391/391 [==============================] - 250s 639ms/step - loss: 0.1608 - val_loss: 0.1698
# Epoch 5/5
# 391/391 [==============================] - 250s 640ms/step - loss: 0.1768 - val_loss: 0.1780
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp61qnr5is.h5
# cnn_pruning with final_sparsity: 0.65
# Epoch 1/5
# 391/391 [==============================] - 262s 669ms/step - loss: 0.1798 - val_loss: 0.1800
# Epoch 2/5
# 391/391 [==============================] - 249s 636ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 3/5
# 391/391 [==============================] - 269s 687ms/step - loss: 0.1799 - val_loss: 0.1795
# Epoch 4/5
# 391/391 [==============================] - 273s 698ms/step - loss: 0.1799 - val_loss: 0.1800
# Epoch 5/5
# 391/391 [==============================] - 265s 679ms/step - loss: 0.1800 - val_loss: 0.1800
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpec07m3sv.h5
# cnn_pruning with final_sparsity: 0.7
# Epoch 1/5
# 391/391 [==============================] - 284s 726ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 2/5
# 391/391 [==============================] - 283s 725ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 3/5
# 391/391 [==============================] - 260s 665ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 4/5
# 391/391 [==============================] - 251s 643ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 5/5
# 391/391 [==============================] - 244s 624ms/step - loss: 0.1800 - val_loss: 0.1800
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp2rnwenh1.h5
# cnn_pruning with final_sparsity: 0.75
# Epoch 1/5
# 391/391 [==============================] - 263s 673ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 2/5
# 391/391 [==============================] - 263s 673ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 3/5
# 391/391 [==============================] - 281s 720ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 4/5
# 391/391 [==============================] - 252s 644ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 5/5
# 391/391 [==============================] - 267s 682ms/step - loss: 0.1800 - val_loss: 0.1800
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmprrra4udl.h5
# cnn_pruning with final_sparsity: 0.8
# Epoch 1/5
# 391/391 [==============================] - 330s 844ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 2/5
# 391/391 [==============================] - 301s 771ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 3/5
# 391/391 [==============================] - 307s 784ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 4/5
# 391/391 [==============================] - 253s 647ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 5/5
# 391/391 [==============================] - 202s 516ms/step - loss: 0.1800 - val_loss: 0.1800
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpwjkyecp4.h5
# cnn_pruning with final_sparsity: 0.85
# Epoch 1/5
# 391/391 [==============================] - 235s 601ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 2/5
# 391/391 [==============================] - 222s 567ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 3/5
# 391/391 [==============================] - 181s 464ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 4/5
# 391/391 [==============================] - 161s 411ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 5/5
# 391/391 [==============================] - 176s 450ms/step - loss: 0.1800 - val_loss: 0.1800
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpev69mfa5.h5
# cnn_pruning with final_sparsity: 0.9
# Epoch 1/5
# 391/391 [==============================] - 141s 362ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 2/5
# 391/391 [==============================] - 141s 361ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 3/5
# 391/391 [==============================] - 140s 359ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 4/5
# 391/391 [==============================] - 103s 264ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 5/5
# 391/391 [==============================] - 101s 259ms/step - loss: 0.1800 - val_loss: 0.1800
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp0k79e22b.h5
# cnn_pruning with final_sparsity: 0.95
# Epoch 1/5
# 391/391 [==============================] - 97s 248ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 2/5
# 391/391 [==============================] - 95s 244ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 3/5
# 391/391 [==============================] - 96s 246ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 4/5
# 391/391 [==============================] - 96s 244ms/step - loss: 0.1800 - val_loss: 0.1800
# Epoch 5/5
# 391/391 [==============================] - 87s 223ms/step - loss: 0.1175 - val_loss: 0.1019
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpeb8w17x9.h5

# %%
synapse_deletion=np.arange(0.05,1.,0.05)


plt.plot(synapse_deletion,err_prun6_list)
plt.plot(synapse_deletion,error6_list)
plt.title("CNN, Categorical Cross Entropy Loss as a function of synapse deletion \n CNN trained on 50 epochs \n + pruning over 5 epochs \n CIFAR10")
plt.xlabel("Synapse percentage deletion")
plt.ylabel("Categorical Cross Entropy Loss")
plt.show()

# %% [markdown]
# ### Observations: Contrary to Autoencoder, pruning up to 80% of weights does not help performance, but pruning between 80% and 95% of weights helps performance on test data
