# %% [markdown]
# # RMSprop - 64 - R2

# %% [markdown]
# Imports

# %%
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras import callbacks
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import Dense, Input, Conv2D, MaxPooling2D, UpSampling2D, Activation, Dropout, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import fashion_mnist, cifar10

import matplotlib.pyplot as plt
import tempfile
# limit GPU memory to stop kernel crashw
#gpu_devices = tf.config.experimental.list_physical_devices('GPU')
#tf.config.experimental.set_memory_growth(gpu_devices[0], True)
#
layers = tf.keras.layers
import numpy as np
print(tf.__version__)
#print (gpu_devices)

from tensorflow.keras.callbacks import EarlyStopping
early_stopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='auto')
import tensorflow_model_optimization as tfmot
# Out:
# 2.3.1

# %%
# Loading Fashion MNIST datset

(train_X, train_Y), (val_X, val_Y) = fashion_mnist.load_data()

# %%
# converting all the pixel values from range(0 to 255) to range(0,1)
train_X = train_X/255.
val_X = val_X/255.

#converting the Image data into values of pixels, i.e. - image of dimension 28 X 28 to single row of 784 pixels(28x28 = 784).
print("Dimension of training data before reshaping",train_X.shape)
train_X = train_X.reshape(-1, 784)
val_X = val_X.reshape(-1, 784)
print("Dimension of training data after reshaping",train_X.shape)
print("Dimension of validation data after reshaping",val_X.shape)
# Out:
# Dimension of training data before reshaping (60000, 28, 28)
# Dimension of training data after reshaping (60000, 784)
# Dimension of validation data after reshaping (10000, 784)

# %% [markdown]
# ### 4) CNN on CIFAR10 dataset

# %%
# CNN

def prepare_cifar10_data(subtract_pixel_mean = True):

    #load cifar10 data and returns the data in the format required

    # The data, split between train and test sets:
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    # Normalize data.
    x_train = x_train.astype('float32') / 255
    x_test = x_test.astype('float32') / 255
    num_classes=10
    # If subtract pixel mean is enabled (Subtracting pixel mean improves accuracy)
    if subtract_pixel_mean:
        x_train_mean = np.mean(x_train, axis=0)
        x_train -= x_train_mean
        x_test -= x_train_mean

    # Convert class vectors to binary class matrices.
    y_train = tensorflow.keras.utils.to_categorical(y_train, num_classes)
    y_test = tensorflow.keras.utils.to_categorical(y_test, num_classes)

    return (x_train, y_train),(x_test,y_test)


def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

def CNN(input_shape, num_classes=10):

    #CNN model for CIFAR10

    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=input_shape))
    model.add(Activation('relu'))
    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(num_classes))
    model.add(Activation('softmax'))

    model.compile(loss='mean_squared_error',
                  optimizer=RMSprop(learning_rate=lr_schedule(0)),
                  metrics=['accuracy'])
    #Categorical crossentropy loss function used

    init = model.get_weights()

    return model, init


def get_gzipped_model_size(file):
    # Returns size of gzipped model, in bytes.
    # Not used here. Used if we wanted to compare compression of models
    import os
    import zipfile

    _, zipped_file = tempfile.mkstemp('.zip')
    with zipfile.ZipFile(zipped_file, 'w', compression=zipfile.ZIP_DEFLATED) as f:
        f.write(file)

    return os.path.getsize(zipped_file)



##Functions for pruning CNN - same as the pruning functions of autoencoders, but for CNN####

def cnn_pruning(model, train_X, train_Y, test_X, test_Y, batch_size, epochs, final_sparsity):

    # Function pruning 5% of weights of model over epochs epochs and returning the error on test data
    # and size of compressed file (not used here)

    prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude
    # Compute end step to finish pruning after epochs epochs.

    num_images = train_X.shape[0]
    end_step = np.ceil(num_images / batch_size).astype(np.int32) * epochs
    print(f'cnn_pruning with final_sparsity: {final_sparsity}')

    # Define model for pruning.
    pruning_params = {
          'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.,
                                                               final_sparsity=final_sparsity,
                                                               begin_step=0,
                                                               end_step=end_step)
    }

    model_pruning = prune_low_magnitude(to_prune=model, **pruning_params)
    # `prune_low_magnitude` requires a recompile.
    model_pruning.compile(optimizer=RMSprop(lr=0.001, epsilon=1e-7), loss='mean_squared_error')
    # Model callbacks
    callbacks = [
      tfmot.sparsity.keras.UpdatePruningStep()
    ]
    # Fitting data
    model_pruning.fit(train_X, train_Y,
                          batch_size=batch_size,
                          validation_data=(test_X,test_Y),
                          epochs=epochs,
                          callbacks=callbacks)
    # Export the model
    model_for_export = tfmot.sparsity.keras.strip_pruning(model_pruning)
    _, pruned_keras_file = tempfile.mkstemp('.h5')
    #save_model(model_for_export, pruned_keras_file, include_optimizer=False)
    model_for_export.save(pruned_keras_file, include_optimizer=False)
    print(f'Pruned model saved: {pruned_keras_file}')

    # to predict the reconstructed images for the original images...
    pred_pruning = model_pruning.predict(test_X)
    cce = tf.keras.losses.MeanSquaredError()
    error_prun=cce(test_Y, pred_pruning).numpy()
    size_pruned_file=get_gzipped_model_size(pruned_keras_file)

    return error_prun, size_pruned_file


def cnn_prune_all(model, train_X, train_Y, test_X, test_Y, batch_size, epochs):

    #####NOTE#####
    # There is a bug in tfmot.sparsity.keras.PolynomialDecay#
    # When I try to pass final_sparsity=final_sparsity it triggers an error
    # When we input a number manually it works
    # Otherwise clearly I would have done a loop
    #########

    # Pruning between 5% and 95% of weights in order to make plot

    err_prun_list=[]
    size_prun_file_list=[]

    for i in range(5, 96, 5):
        error_prun, size_pruned_file = cnn_pruning(model=model, train_X=train_X, train_Y=train_Y, test_X=test_X,
                                                   test_Y=test_Y, batch_size=batch_size,epochs=epochs, final_sparsity=i / 100.0)
        err_prun_list.append(error_prun)
        size_prun_file_list.append(size_pruned_file)

    return err_prun_list, size_prun_file_list

# %%
num_classes=10
#Loading CIFAR10 data (10 classes)
(x_train,y_train),(x_test,y_test) = prepare_cifar10_data(subtract_pixel_mean=True)

# Making CNN model
cnn_cifar, init = CNN(input_shape=x_train.shape[1:])
# Training CNN model 50 epochs
cnn_cifar.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test), callbacks=[early_stopper])

#calculating Categorical crossentropy loss on test data
pred6 = cnn_cifar.predict(x_test)
cce = tf.keras.losses.MeanSquaredError()

error6=cce(y_test, pred6).numpy()
print(error6)
error6_list=np.ones(19)*error6

#Pruning CNN and getting errors per percentage of synapses pruned

err_prun6_list, size_prun6_file_list = cnn_prune_all(model=cnn_cifar, train_X=x_train, train_Y=y_train,
                                                    test_X=x_test, test_Y=y_test, batch_size=128, epochs=5)
# Out:
# Learning rate:  0.001
# Epoch 1/50
# 391/391 [==============================] - 349s 893ms/step - loss: 0.0692 - accuracy: 0.4381 - val_loss: 0.0569 - val_accuracy: 0.5710
# Epoch 2/50
# 391/391 [==============================] - 362s 927ms/step - loss: 0.0512 - accuracy: 0.6165 - val_loss: 0.0502 - val_accuracy: 0.6269
# Epoch 3/50
# 391/391 [==============================] - 330s 844ms/step - loss: 0.0411 - accuracy: 0.6987 - val_loss: 0.0396 - val_accuracy: 0.7117
# Epoch 4/50
# 391/391 [==============================] - 315s 807ms/step - loss: 0.0336 - accuracy: 0.7598 - val_loss: 0.0416 - val_accuracy: 0.6999
# Epoch 5/50
# 391/391 [==============================] - 315s 804ms/step - loss: 0.0280 - accuracy: 0.8033 - val_loss: 0.0359 - val_accuracy: 0.7445
# Epoch 6/50
# 391/391 [==============================] - 297s 761ms/step - loss: 0.0227 - accuracy: 0.8447 - val_loss: 0.0383 - val_accuracy: 0.7344
# Epoch 7/50
# 391/391 [==============================] - 289s 739ms/step - loss: 0.0183 - accuracy: 0.8777 - val_loss: 0.0363 - val_accuracy: 0.7491
# Epoch 8/50
# 391/391 [==============================] - 288s 738ms/step - loss: 0.0145 - accuracy: 0.9042 - val_loss: 0.0366 - val_accuracy: 0.7561
# Epoch 9/50
# 391/391 [==============================] - 287s 734ms/step - loss: 0.0119 - accuracy: 0.9236 - val_loss: 0.0383 - val_accuracy: 0.7537
# Epoch 10/50
# 391/391 [==============================] - 270s 691ms/step - loss: 0.0099 - accuracy: 0.9370 - val_loss: 0.0395 - val_accuracy: 0.7520
# Epoch 11/50
# 391/391 [==============================] - 288s 736ms/step - loss: 0.0087 - accuracy: 0.9451 - val_loss: 0.0396 - val_accuracy: 0.7489
# Epoch 12/50
# 391/391 [==============================] - 264s 676ms/step - loss: 0.0076 - accuracy: 0.9524 - val_loss: 0.0398 - val_accuracy: 0.7489
# Epoch 13/50
# 391/391 [==============================] - 289s 739ms/step - loss: 0.0070 - accuracy: 0.9567 - val_loss: 0.0412 - val_accuracy: 0.7458
# Epoch 14/50
# 391/391 [==============================] - 285s 728ms/step - loss: 0.0066 - accuracy: 0.9594 - val_loss: 0.0404 - val_accuracy: 0.7549
# Epoch 15/50
# 391/391 [==============================] - 274s 702ms/step - loss: 0.0061 - accuracy: 0.9632 - val_loss: 0.0412 - val_accuracy: 0.7516
# Epoch 00015: early stopping
# 0.041206874
# cnn_pruning with final_sparsity: 0.05
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/sparsity/keras/pruning_wrapper.py:200: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# Epoch 1/5
# 391/391 [==============================] - 271s 693ms/step - loss: 0.0060 - val_loss: 0.0423
# Epoch 2/5
# 391/391 [==============================] - 279s 714ms/step - loss: 0.0054 - val_loss: 0.0423
# Epoch 3/5
# 391/391 [==============================] - 286s 731ms/step - loss: 0.0052 - val_loss: 0.0436
# Epoch 4/5
# 391/391 [==============================] - 277s 708ms/step - loss: 0.0049 - val_loss: 0.0435
# Epoch 5/5
# 391/391 [==============================] - 276s 706ms/step - loss: 0.0051 - val_loss: 0.0430
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpa6t0z6bz.h5
# cnn_pruning with final_sparsity: 0.1
# Epoch 1/5
# 391/391 [==============================] - 281s 719ms/step - loss: 0.0053 - val_loss: 0.0432
# Epoch 2/5
# 391/391 [==============================] - 274s 700ms/step - loss: 0.0050 - val_loss: 0.0449
# Epoch 3/5
# 391/391 [==============================] - 278s 711ms/step - loss: 0.0046 - val_loss: 0.0462
# Epoch 4/5
# 391/391 [==============================] - 279s 714ms/step - loss: 0.0048 - val_loss: 0.0432
# Epoch 5/5
# 391/391 [==============================] - 278s 712ms/step - loss: 0.0045 - val_loss: 0.0452
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpm8q4wfau.h5
# cnn_pruning with final_sparsity: 0.15
# Epoch 1/5
# 391/391 [==============================] - 279s 713ms/step - loss: 0.0050 - val_loss: 0.0489
# Epoch 2/5
# 391/391 [==============================] - 262s 671ms/step - loss: 0.0049 - val_loss: 0.0463
# Epoch 3/5
# 391/391 [==============================] - 273s 698ms/step - loss: 0.0048 - val_loss: 0.0458
# Epoch 4/5
# 391/391 [==============================] - 296s 757ms/step - loss: 0.0046 - val_loss: 0.0464
# Epoch 5/5
# 391/391 [==============================] - 265s 677ms/step - loss: 0.0046 - val_loss: 0.0457
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpxmc63oqz.h5
# cnn_pruning with final_sparsity: 0.2
# Epoch 1/5
# 391/391 [==============================] - 279s 714ms/step - loss: 0.0052 - val_loss: 0.0470
# Epoch 2/5
# 391/391 [==============================] - 255s 651ms/step - loss: 0.0047 - val_loss: 0.0461
# Epoch 3/5
# 391/391 [==============================] - 283s 724ms/step - loss: 0.0046 - val_loss: 0.0458
# Epoch 4/5
# 391/391 [==============================] - 290s 742ms/step - loss: 0.0046 - val_loss: 0.0471
# Epoch 5/5
# 391/391 [==============================] - 254s 650ms/step - loss: 0.0044 - val_loss: 0.0462
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpkwuslj0_.h5
# cnn_pruning with final_sparsity: 0.25
# Epoch 1/5
# 391/391 [==============================] - 286s 732ms/step - loss: 0.0057 - val_loss: 0.0490
# Epoch 2/5
# 391/391 [==============================] - 278s 711ms/step - loss: 0.0054 - val_loss: 0.0470
# Epoch 3/5
# 391/391 [==============================] - 285s 728ms/step - loss: 0.0048 - val_loss: 0.0477
# Epoch 4/5
# 391/391 [==============================] - 269s 687ms/step - loss: 0.0049 - val_loss: 0.0466
# Epoch 5/5
# 391/391 [==============================] - 269s 687ms/step - loss: 0.0047 - val_loss: 0.0473
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmptmn6c7iu.h5
# cnn_pruning with final_sparsity: 0.3
# Epoch 1/5
# 391/391 [==============================] - 281s 719ms/step - loss: 0.0060 - val_loss: 0.0489
# Epoch 2/5
# 391/391 [==============================] - 289s 739ms/step - loss: 0.0050 - val_loss: 0.0478
# Epoch 3/5
# 391/391 [==============================] - 261s 667ms/step - loss: 0.0053 - val_loss: 0.0490
# Epoch 4/5
# 391/391 [==============================] - 274s 701ms/step - loss: 0.0050 - val_loss: 0.0477
# Epoch 5/5
# 391/391 [==============================] - 278s 711ms/step - loss: 0.0049 - val_loss: 0.0487
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpbe99suyr.h5
# cnn_pruning with final_sparsity: 0.35
# Epoch 1/5
# 391/391 [==============================] - 276s 706ms/step - loss: 0.0064 - val_loss: 0.0492
# Epoch 2/5
# 391/391 [==============================] - 288s 737ms/step - loss: 0.0056 - val_loss: 0.0492
# Epoch 3/5
# 391/391 [==============================] - 260s 665ms/step - loss: 0.0052 - val_loss: 0.0482
# Epoch 4/5
# 391/391 [==============================] - 274s 702ms/step - loss: 0.0050 - val_loss: 0.0483
# Epoch 5/5
# 391/391 [==============================] - 275s 704ms/step - loss: 0.0047 - val_loss: 0.0485
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpkwvm11a0.h5
# cnn_pruning with final_sparsity: 0.4
# Epoch 1/5
# 391/391 [==============================] - 262s 671ms/step - loss: 0.0065 - val_loss: 0.0486
# Epoch 2/5
# 391/391 [==============================] - 291s 743ms/step - loss: 0.0053 - val_loss: 0.0483
# Epoch 3/5
# 391/391 [==============================] - 274s 700ms/step - loss: 0.0048 - val_loss: 0.0512
# Epoch 4/5
# 391/391 [==============================] - 258s 659ms/step - loss: 0.0052 - val_loss: 0.0472
# Epoch 5/5
# 391/391 [==============================] - 260s 664ms/step - loss: 0.0049 - val_loss: 0.0473
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpnl75st_k.h5
# cnn_pruning with final_sparsity: 0.45
# Epoch 1/5
# 391/391 [==============================] - 268s 686ms/step - loss: 0.0075 - val_loss: 0.0502
# Epoch 2/5
# 391/391 [==============================] - 294s 753ms/step - loss: 0.0062 - val_loss: 0.0487
# Epoch 3/5
# 391/391 [==============================] - 289s 739ms/step - loss: 0.0051 - val_loss: 0.0489
# Epoch 4/5
# 391/391 [==============================] - 245s 626ms/step - loss: 0.0053 - val_loss: 0.0495
# Epoch 5/5
# 391/391 [==============================] - 259s 664ms/step - loss: 0.0049 - val_loss: 0.0487
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpix5v7w0v.h5
# cnn_pruning with final_sparsity: 0.5
# Epoch 1/5
# 391/391 [==============================] - 230s 588ms/step - loss: 0.0082 - val_loss: 0.0496
# Epoch 2/5
# 391/391 [==============================] - 231s 592ms/step - loss: 0.0063 - val_loss: 0.0478
# Epoch 3/5
# 391/391 [==============================] - 247s 631ms/step - loss: 0.0049 - val_loss: 0.0484
# Epoch 4/5
# 391/391 [==============================] - 220s 562ms/step - loss: 0.0054 - val_loss: 0.0482
# Epoch 5/5
# 391/391 [==============================] - 236s 603ms/step - loss: 0.0052 - val_loss: 0.0503
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpcew0fmm6.h5
# cnn_pruning with final_sparsity: 0.55
# Epoch 1/5
# 391/391 [==============================] - 251s 643ms/step - loss: 0.0090 - val_loss: 0.0513
# Epoch 2/5
# 391/391 [==============================] - 227s 580ms/step - loss: 0.0066 - val_loss: 0.0489
# Epoch 3/5
# 391/391 [==============================] - 250s 640ms/step - loss: 0.0049 - val_loss: 0.0483
# Epoch 4/5
# 391/391 [==============================] - 239s 611ms/step - loss: 0.0056 - val_loss: 0.0491
# Epoch 5/5
# 391/391 [==============================] - 216s 553ms/step - loss: 0.0057 - val_loss: 0.0482
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpdcvp8pcx.h5
# cnn_pruning with final_sparsity: 0.6
# Epoch 1/5
# 391/391 [==============================] - 232s 593ms/step - loss: 0.0093 - val_loss: 0.0491
# Epoch 2/5
# 391/391 [==============================] - 250s 640ms/step - loss: 0.0068 - val_loss: 0.0493
# Epoch 3/5
# 391/391 [==============================] - 254s 649ms/step - loss: 0.0053 - val_loss: 0.0477
# Epoch 4/5
# 391/391 [==============================] - 269s 687ms/step - loss: 0.0060 - val_loss: 0.0479
# Epoch 5/5
# 391/391 [==============================] - 234s 598ms/step - loss: 0.0062 - val_loss: 0.0485
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpsm13h2ys.h5
# cnn_pruning with final_sparsity: 0.65
# Epoch 1/5
# 391/391 [==============================] - 243s 622ms/step - loss: 0.0108 - val_loss: 0.0520
# Epoch 2/5
# 391/391 [==============================] - 270s 690ms/step - loss: 0.0079 - val_loss: 0.0489
# Epoch 3/5
# 391/391 [==============================] - 250s 638ms/step - loss: 0.0056 - val_loss: 0.0471
# Epoch 4/5
# 391/391 [==============================] - 257s 658ms/step - loss: 0.0070 - val_loss: 0.0496
# Epoch 5/5
# 391/391 [==============================] - 224s 574ms/step - loss: 0.0070 - val_loss: 0.0492
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpz2ljbbj2.h5
# cnn_pruning with final_sparsity: 0.7
# Epoch 1/5
# 391/391 [==============================] - 227s 580ms/step - loss: 0.0120 - val_loss: 0.0504
# Epoch 2/5
# 391/391 [==============================] - 246s 630ms/step - loss: 0.0086 - val_loss: 0.0489
# Epoch 3/5
# 391/391 [==============================] - 238s 608ms/step - loss: 0.0060 - val_loss: 0.0482
# Epoch 4/5
# 391/391 [==============================] - 256s 655ms/step - loss: 0.0079 - val_loss: 0.0492
# Epoch 5/5
# 391/391 [==============================] - 268s 686ms/step - loss: 0.0080 - val_loss: 0.0483
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpum94rwwo.h5
# cnn_pruning with final_sparsity: 0.75
# Epoch 1/5
# 391/391 [==============================] - 248s 634ms/step - loss: 0.0136 - val_loss: 0.0498
# Epoch 2/5
# 391/391 [==============================] - 257s 657ms/step - loss: 0.0094 - val_loss: 0.0474
# Epoch 3/5
# 391/391 [==============================] - 267s 683ms/step - loss: 0.0064 - val_loss: 0.0486
# Epoch 4/5
# 391/391 [==============================] - 227s 581ms/step - loss: 0.0087 - val_loss: 0.0499
# Epoch 5/5
# 391/391 [==============================] - 246s 628ms/step - loss: 0.0091 - val_loss: 0.0491
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp1s5qqms6.h5
# cnn_pruning with final_sparsity: 0.8
# Epoch 1/5
# 391/391 [==============================] - 213s 544ms/step - loss: 0.0143 - val_loss: 0.0494
# Epoch 2/5
# 391/391 [==============================] - 225s 575ms/step - loss: 0.0092 - val_loss: 0.0499
# Epoch 3/5
# 391/391 [==============================] - 249s 637ms/step - loss: 0.0063 - val_loss: 0.0477
# Epoch 4/5
# 391/391 [==============================] - 247s 633ms/step - loss: 0.0097 - val_loss: 0.0492
# Epoch 5/5
# 391/391 [==============================] - 267s 684ms/step - loss: 0.0102 - val_loss: 0.0485
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpkbalk4z1.h5
# cnn_pruning with final_sparsity: 0.85
# Epoch 1/5
# 391/391 [==============================] - 217s 554ms/step - loss: 0.0150 - val_loss: 0.0500
# Epoch 2/5
# 391/391 [==============================] - 260s 664ms/step - loss: 0.0090 - val_loss: 0.0464
# Epoch 3/5
# 391/391 [==============================] - 264s 676ms/step - loss: 0.0061 - val_loss: 0.0459
# Epoch 4/5
# 391/391 [==============================] - 251s 642ms/step - loss: 0.0107 - val_loss: 0.0487
# Epoch 5/5
# 391/391 [==============================] - 233s 595ms/step - loss: 0.0127 - val_loss: 0.0452
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpabnk7017.h5
# cnn_pruning with final_sparsity: 0.9
# Epoch 1/5
# 391/391 [==============================] - 225s 575ms/step - loss: 0.0163 - val_loss: 0.0450
# Epoch 2/5
# 391/391 [==============================] - 233s 596ms/step - loss: 0.0075 - val_loss: 0.0433
# Epoch 3/5
# 391/391 [==============================] - 229s 586ms/step - loss: 0.0052 - val_loss: 0.0434
# Epoch 4/5
# 391/391 [==============================] - 267s 684ms/step - loss: 0.0146 - val_loss: 0.0442
# Epoch 5/5
# 391/391 [==============================] - 244s 623ms/step - loss: 0.0185 - val_loss: 0.0392
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpge28n6ya.h5
# cnn_pruning with final_sparsity: 0.95
# Epoch 1/5
# 391/391 [==============================] - 277s 709ms/step - loss: 0.0178 - val_loss: 0.0394
# Epoch 2/5
# 391/391 [==============================] - 226s 578ms/step - loss: 0.0070 - val_loss: 0.0384
# Epoch 3/5
# 391/391 [==============================] - 301s 770ms/step - loss: 0.0050 - val_loss: 0.0392
# Epoch 4/5
# 391/391 [==============================] - 288s 737ms/step - loss: 0.0270 - val_loss: 0.0482
# Epoch 5/5
# 391/391 [==============================] - 287s 733ms/step - loss: 0.0404 - val_loss: 0.0418
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp5y5ehw08.h5

# %%
synapse_deletion=np.arange(0.05,1.,0.05)


plt.plot(synapse_deletion,err_prun6_list)
plt.plot(synapse_deletion,error6_list)
plt.title("CNN, Categorical Cross Entropy Loss as a function of synapse deletion \n CNN trained on 50 epochs \n + pruning over 5 epochs \n CIFAR10")
plt.xlabel("Synapse percentage deletion")
plt.ylabel("Categorical Cross Entropy Loss")
plt.show()

# %% [markdown]
# ### Observations: Contrary to Autoencoder, pruning up to 80% of weights does not help performance, but pruning between 80% and 95% of weights helps performance on test data
