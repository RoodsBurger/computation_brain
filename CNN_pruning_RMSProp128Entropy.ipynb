# %% [markdown]
# # RMSprop - 128 - Entropy

# %% [markdown]
# Imports

# %%
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras import callbacks
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import Dense, Input, Conv2D, MaxPooling2D, UpSampling2D, Activation, Dropout, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import fashion_mnist, cifar10

import matplotlib.pyplot as plt
import tempfile
# limit GPU memory to stop kernel crashw
#gpu_devices = tf.config.experimental.list_physical_devices('GPU')
#tf.config.experimental.set_memory_growth(gpu_devices[0], True)
#
layers = tf.keras.layers
import numpy as np
print(tf.__version__)
#print (gpu_devices)

from tensorflow.keras.callbacks import EarlyStopping
early_stopper = EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1, mode='auto')
import tensorflow_model_optimization as tfmot
# Out:
# 2.3.1

# %%
# Loading Fashion MNIST datset

(train_X, train_Y), (val_X, val_Y) = fashion_mnist.load_data()

# %%
# converting all the pixel values from range(0 to 255) to range(0,1)
train_X = train_X/255.
val_X = val_X/255.

#converting the Image data into values of pixels, i.e. - image of dimension 28 X 28 to single row of 784 pixels(28x28 = 784).
print("Dimension of training data before reshaping",train_X.shape)
train_X = train_X.reshape(-1, 784)
val_X = val_X.reshape(-1, 784)
print("Dimension of training data after reshaping",train_X.shape)
print("Dimension of validation data after reshaping",val_X.shape)
# Out:
# Dimension of training data before reshaping (60000, 28, 28)
# Dimension of training data after reshaping (60000, 784)
# Dimension of validation data after reshaping (10000, 784)

# %% [markdown]
# ### 4) CNN on CIFAR10 dataset

# %%
# CNN

def prepare_cifar10_data(subtract_pixel_mean = True):

    #load cifar10 data and returns the data in the format required

    # The data, split between train and test sets:
    (x_train, y_train), (x_test, y_test) = cifar10.load_data()
    # Normalize data.
    x_train = x_train.astype('float32') / 255
    x_test = x_test.astype('float32') / 255
    num_classes=10
    # If subtract pixel mean is enabled (Subtracting pixel mean improves accuracy)
    if subtract_pixel_mean:
        x_train_mean = np.mean(x_train, axis=0)
        x_train -= x_train_mean
        x_test -= x_train_mean

    # Convert class vectors to binary class matrices.
    y_train = tensorflow.keras.utils.to_categorical(y_train, num_classes)
    y_test = tensorflow.keras.utils.to_categorical(y_test, num_classes)

    return (x_train, y_train),(x_test,y_test)


def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

def CNN(input_shape, num_classes=10):

    #CNN model for CIFAR10

    model = Sequential()
    model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=input_shape))
    model.add(Activation('relu'))
    model.add(Conv2D(32, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(64, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(128, (3, 3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv2D(128, (3, 3)))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(num_classes))
    model.add(Activation('softmax'))

    model.compile(loss='categorical_crossentropy',
                  optimizer=RMSprop(learning_rate=lr_schedule(0)),
                  metrics=['accuracy'])
    #Categorical crossentropy loss function used

    init = model.get_weights()

    return model, init


def get_gzipped_model_size(file):
    # Returns size of gzipped model, in bytes.
    # Not used here. Used if we wanted to compare compression of models
    import os
    import zipfile

    _, zipped_file = tempfile.mkstemp('.zip')
    with zipfile.ZipFile(zipped_file, 'w', compression=zipfile.ZIP_DEFLATED) as f:
        f.write(file)

    return os.path.getsize(zipped_file)



##Functions for pruning CNN - same as the pruning functions of autoencoders, but for CNN####

def cnn_pruning(model, train_X, train_Y, test_X, test_Y, batch_size, epochs, final_sparsity):

    # Function pruning 5% of weights of model over epochs epochs and returning the error on test data
    # and size of compressed file (not used here)

    prune_low_magnitude = tfmot.sparsity.keras.prune_low_magnitude
    # Compute end step to finish pruning after epochs epochs.

    num_images = train_X.shape[0]
    end_step = np.ceil(num_images / batch_size).astype(np.int32) * epochs
    print(f'cnn_pruning with final_sparsity: {final_sparsity}')

    # Define model for pruning.
    pruning_params = {
          'pruning_schedule': tfmot.sparsity.keras.PolynomialDecay(initial_sparsity=0.,
                                                               final_sparsity=final_sparsity,
                                                               begin_step=0,
                                                               end_step=end_step)
    }

    model_pruning = prune_low_magnitude(to_prune=model, **pruning_params)
    # `prune_low_magnitude` requires a recompile.
    model_pruning.compile(optimizer=RMSprop(lr=0.001, epsilon=1e-7), loss='categorical_crossentropy')
    # Model callbacks
    callbacks = [
      tfmot.sparsity.keras.UpdatePruningStep()
    ]
    # Fitting data
    model_pruning.fit(train_X, train_Y,
                          batch_size=batch_size,
                          validation_data=(test_X,test_Y),
                          epochs=epochs,
                          callbacks=callbacks)
    # Export the model
    model_for_export = tfmot.sparsity.keras.strip_pruning(model_pruning)
    _, pruned_keras_file = tempfile.mkstemp('.h5')
    #save_model(model_for_export, pruned_keras_file, include_optimizer=False)
    model_for_export.save(pruned_keras_file, include_optimizer=False)
    print(f'Pruned model saved: {pruned_keras_file}')

    # to predict the reconstructed images for the original images...
    pred_pruning = model_pruning.predict(test_X)
    cce = tf.keras.losses.CategoricalCrossentropy()
    error_prun=cce(test_Y, pred_pruning).numpy()
    size_pruned_file=get_gzipped_model_size(pruned_keras_file)

    return error_prun, size_pruned_file


def cnn_prune_all(model, train_X, train_Y, test_X, test_Y, batch_size, epochs):

    #####NOTE#####
    # There is a bug in tfmot.sparsity.keras.PolynomialDecay#
    # When I try to pass final_sparsity=final_sparsity it triggers an error
    # When we input a number manually it works
    # Otherwise clearly I would have done a loop
    #########

    # Pruning between 5% and 95% of weights in order to make plot

    err_prun_list=[]
    size_prun_file_list=[]

    for i in range(5, 96, 5):
        error_prun, size_pruned_file = cnn_pruning(model=model, train_X=train_X, train_Y=train_Y, test_X=test_X,
                                                   test_Y=test_Y, batch_size=batch_size,epochs=epochs, final_sparsity=i / 100.0)
        err_prun_list.append(error_prun)
        size_prun_file_list.append(size_pruned_file)

    return err_prun_list, size_prun_file_list

# %%
num_classes=10
#Loading CIFAR10 data (10 classes)
(x_train,y_train),(x_test,y_test) = prepare_cifar10_data(subtract_pixel_mean=True)

# Making CNN model
cnn_cifar, init = CNN(input_shape=x_train.shape[1:])
# Training CNN model 50 epochs
cnn_cifar.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test), callbacks=[early_stopper])

#calculating Categorical crossentropy loss on test data
pred6 = cnn_cifar.predict(x_test)
cce = tf.keras.losses.CategoricalCrossentropy()

error6=cce(y_test, pred6).numpy()
print(error6)
error6_list=np.ones(19)*error6

#Pruning CNN and getting errors per percentage of synapses pruned

err_prun6_list, size_prun6_file_list =cnn_prune_all(model=cnn_cifar, train_X=x_train, train_Y=y_train,
                                                    test_X=x_test, test_Y=y_test, batch_size=128, epochs=5)
# Out:
# Learning rate:  0.001
# Epoch 1/50
# 391/391 [==============================] - 397s 1s/step - loss: 1.7097 - accuracy: 0.3775 - val_loss: 1.4309 - val_accuracy: 0.4785
# Epoch 2/50
# 391/391 [==============================] - 394s 1s/step - loss: 1.2477 - accuracy: 0.5542 - val_loss: 1.1239 - val_accuracy: 0.5913
# Epoch 3/50
# 391/391 [==============================] - 354s 905ms/step - loss: 1.0074 - accuracy: 0.6427 - val_loss: 0.9233 - val_accuracy: 0.6765
# Epoch 4/50
# 391/391 [==============================] - 344s 881ms/step - loss: 0.8320 - accuracy: 0.7070 - val_loss: 0.8291 - val_accuracy: 0.7076
# Epoch 5/50
# 391/391 [==============================] - 334s 855ms/step - loss: 0.6977 - accuracy: 0.7566 - val_loss: 0.7826 - val_accuracy: 0.7353
# Epoch 6/50
# 391/391 [==============================] - 316s 809ms/step - loss: 0.5899 - accuracy: 0.7941 - val_loss: 0.7581 - val_accuracy: 0.7531
# Epoch 7/50
# 391/391 [==============================] - 316s 807ms/step - loss: 0.4966 - accuracy: 0.8253 - val_loss: 0.7504 - val_accuracy: 0.7533
# Epoch 8/50
# 391/391 [==============================] - 313s 801ms/step - loss: 0.4136 - accuracy: 0.8539 - val_loss: 0.7716 - val_accuracy: 0.7631
# Epoch 9/50
# 391/391 [==============================] - 297s 759ms/step - loss: 0.3399 - accuracy: 0.8814 - val_loss: 0.8073 - val_accuracy: 0.7627
# Epoch 10/50
# 391/391 [==============================] - 314s 802ms/step - loss: 0.2775 - accuracy: 0.9007 - val_loss: 0.8051 - val_accuracy: 0.7730
# Epoch 11/50
# 391/391 [==============================] - 293s 749ms/step - loss: 0.2275 - accuracy: 0.9202 - val_loss: 0.9752 - val_accuracy: 0.7659
# Epoch 12/50
# 391/391 [==============================] - 313s 801ms/step - loss: 0.1888 - accuracy: 0.9329 - val_loss: 1.1396 - val_accuracy: 0.7588
# Epoch 13/50
# 391/391 [==============================] - 313s 802ms/step - loss: 0.1610 - accuracy: 0.9442 - val_loss: 1.2349 - val_accuracy: 0.7544
# Epoch 14/50
# 391/391 [==============================] - 280s 717ms/step - loss: 0.1419 - accuracy: 0.9521 - val_loss: 1.1801 - val_accuracy: 0.7669
# Epoch 15/50
# 391/391 [==============================] - 280s 716ms/step - loss: 0.1281 - accuracy: 0.9568 - val_loss: 1.4682 - val_accuracy: 0.7488
# Epoch 16/50
# 391/391 [==============================] - 293s 750ms/step - loss: 0.1235 - accuracy: 0.9579 - val_loss: 1.2335 - val_accuracy: 0.7704
# Epoch 17/50
# 391/391 [==============================] - 304s 779ms/step - loss: 0.1120 - accuracy: 0.9628 - val_loss: 1.4719 - val_accuracy: 0.7731
# Epoch 00017: early stopping
# 1.3935431
# cnn_pruning with final_sparsity: 0.05
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow_model_optimization/python/core/sparsity/keras/pruning_wrapper.py:200: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# Epoch 1/5
# 391/391 [==============================] - 305s 779ms/step - loss: 0.1153 - val_loss: 1.4541
# Epoch 2/5
# 391/391 [==============================] - 289s 739ms/step - loss: 0.1014 - val_loss: 1.4451
# Epoch 3/5
# 391/391 [==============================] - 282s 721ms/step - loss: 0.0980 - val_loss: 1.6661
# Epoch 4/5
# 391/391 [==============================] - 292s 748ms/step - loss: 0.0945 - val_loss: 1.8272
# Epoch 5/5
# 391/391 [==============================] - 313s 799ms/step - loss: 0.0937 - val_loss: 1.7561
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp12tsuph3.h5
# cnn_pruning with final_sparsity: 0.1
# Epoch 1/5
# 391/391 [==============================] - 307s 784ms/step - loss: 0.1083 - val_loss: 1.5720
# Epoch 2/5
# 391/391 [==============================] - 291s 744ms/step - loss: 0.0941 - val_loss: 1.6882
# Epoch 3/5
# 391/391 [==============================] - 272s 697ms/step - loss: 0.0930 - val_loss: 1.5498
# Epoch 4/5
# 391/391 [==============================] - 291s 743ms/step - loss: 0.0881 - val_loss: 1.8160
# Epoch 5/5
# 391/391 [==============================] - 316s 808ms/step - loss: 0.0900 - val_loss: 1.9865
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpi4vmurpl.h5
# cnn_pruning with final_sparsity: 0.15
# Epoch 1/5
# 391/391 [==============================] - 322s 824ms/step - loss: 0.1148 - val_loss: 2.7087
# Epoch 2/5
# 391/391 [==============================] - 296s 757ms/step - loss: 0.0967 - val_loss: 2.7567
# Epoch 3/5
# 391/391 [==============================] - 276s 706ms/step - loss: 0.0947 - val_loss: 2.1044
# Epoch 4/5
# 391/391 [==============================] - 294s 751ms/step - loss: 0.0881 - val_loss: 2.3823
# Epoch 5/5
# 391/391 [==============================] - 307s 786ms/step - loss: 0.0818 - val_loss: 2.0482
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpkh1zyyp9.h5
# cnn_pruning with final_sparsity: 0.2
# Epoch 1/5
# 391/391 [==============================] - 305s 780ms/step - loss: 0.1321 - val_loss: 2.0788
# Epoch 2/5
# 391/391 [==============================] - 309s 789ms/step - loss: 0.1009 - val_loss: 2.5102
# Epoch 3/5
# 391/391 [==============================] - 286s 732ms/step - loss: 0.0932 - val_loss: 2.6577
# Epoch 4/5
# 391/391 [==============================] - 286s 732ms/step - loss: 0.0878 - val_loss: 2.2056
# Epoch 5/5
# 391/391 [==============================] - 295s 754ms/step - loss: 0.1011 - val_loss: 2.0618
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpo23py3z2.h5
# cnn_pruning with final_sparsity: 0.25
# Epoch 1/5
# 391/391 [==============================] - 299s 765ms/step - loss: 0.1424 - val_loss: 2.1128
# Epoch 2/5
# 391/391 [==============================] - 306s 783ms/step - loss: 0.1108 - val_loss: 2.3943
# Epoch 3/5
# 391/391 [==============================] - 279s 713ms/step - loss: 0.0973 - val_loss: 2.6168
# Epoch 4/5
# 391/391 [==============================] - 291s 744ms/step - loss: 0.0962 - val_loss: 2.1220
# Epoch 5/5
# 391/391 [==============================] - 292s 747ms/step - loss: 0.0844 - val_loss: 3.5422
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpusyp2y9t.h5
# cnn_pruning with final_sparsity: 0.3
# Epoch 1/5
# 391/391 [==============================] - 305s 780ms/step - loss: 0.1617 - val_loss: 2.6534
# Epoch 2/5
# 391/391 [==============================] - 306s 783ms/step - loss: 0.1096 - val_loss: 2.1612
# Epoch 3/5
# 391/391 [==============================] - 277s 710ms/step - loss: 0.1102 - val_loss: 2.3600
# Epoch 4/5
# 391/391 [==============================] - 277s 708ms/step - loss: 0.0999 - val_loss: 2.3786
# Epoch 5/5
# 391/391 [==============================] - 297s 759ms/step - loss: 0.0854 - val_loss: 2.2597
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp5pe_s40v.h5
# cnn_pruning with final_sparsity: 0.35
# Epoch 1/5
# 391/391 [==============================] - 315s 805ms/step - loss: 0.1688 - val_loss: 2.5074
# Epoch 2/5
# 391/391 [==============================] - 301s 770ms/step - loss: 0.1004 - val_loss: 2.9632
# Epoch 3/5
# 391/391 [==============================] - 270s 690ms/step - loss: 0.0938 - val_loss: 2.6964
# Epoch 4/5
# 391/391 [==============================] - 276s 706ms/step - loss: 0.0975 - val_loss: 2.6626
# Epoch 5/5
# 391/391 [==============================] - 285s 729ms/step - loss: 0.0908 - val_loss: 3.0526
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp8kavc9mm.h5
# cnn_pruning with final_sparsity: 0.4
# Epoch 1/5
# 391/391 [==============================] - 325s 831ms/step - loss: 0.1887 - val_loss: 2.5726
# Epoch 2/5
# 391/391 [==============================] - 300s 768ms/step - loss: 0.1007 - val_loss: 2.6825
# Epoch 3/5
# 391/391 [==============================] - 262s 671ms/step - loss: 0.0841 - val_loss: 3.5472
# Epoch 4/5
# 391/391 [==============================] - 265s 677ms/step - loss: 0.1088 - val_loss: 3.1499
# Epoch 5/5
# 391/391 [==============================] - 241s 617ms/step - loss: 0.0901 - val_loss: 3.1674
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp9hx2yudo.h5
# cnn_pruning with final_sparsity: 0.45
# Epoch 1/5
# 391/391 [==============================] - 270s 689ms/step - loss: 0.1892 - val_loss: 3.2974
# Epoch 2/5
# 391/391 [==============================] - 258s 661ms/step - loss: 0.0902 - val_loss: 3.0357
# Epoch 3/5
# 391/391 [==============================] - 239s 610ms/step - loss: 0.0701 - val_loss: 3.4793
# Epoch 4/5
# 391/391 [==============================] - 229s 586ms/step - loss: 0.1068 - val_loss: 3.3059
# Epoch 5/5
# 391/391 [==============================] - 245s 626ms/step - loss: 0.0870 - val_loss: 3.1893
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpfevaxmrv.h5
# cnn_pruning with final_sparsity: 0.5
# Epoch 1/5
# 391/391 [==============================] - 276s 705ms/step - loss: 0.2118 - val_loss: 3.5971
# Epoch 2/5
# 391/391 [==============================] - 256s 654ms/step - loss: 0.0822 - val_loss: 2.6234
# Epoch 3/5
# 391/391 [==============================] - 234s 598ms/step - loss: 0.0642 - val_loss: 3.2516
# Epoch 4/5
# 391/391 [==============================] - 223s 570ms/step - loss: 0.1081 - val_loss: 3.5392
# Epoch 5/5
# 391/391 [==============================] - 267s 684ms/step - loss: 0.0851 - val_loss: 3.0333
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmph7_8443l.h5
# cnn_pruning with final_sparsity: 0.55
# Epoch 1/5
# 391/391 [==============================] - 291s 743ms/step - loss: 0.2193 - val_loss: 3.0195
# Epoch 2/5
# 391/391 [==============================] - 282s 721ms/step - loss: 0.0760 - val_loss: 3.2734
# Epoch 3/5
# 391/391 [==============================] - 246s 629ms/step - loss: 0.0529 - val_loss: 3.4511
# Epoch 4/5
# 391/391 [==============================] - 255s 651ms/step - loss: 0.1241 - val_loss: 3.4238
# Epoch 5/5
# 391/391 [==============================] - 289s 739ms/step - loss: 0.0967 - val_loss: 3.5849
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp26qsrokn.h5
# cnn_pruning with final_sparsity: 0.6
# Epoch 1/5
# 391/391 [==============================] - 290s 742ms/step - loss: 0.2349 - val_loss: 2.4611
# Epoch 2/5
# 391/391 [==============================] - 247s 631ms/step - loss: 0.0812 - val_loss: 2.6441
# Epoch 3/5
# 391/391 [==============================] - 231s 591ms/step - loss: 0.0483 - val_loss: 3.2357
# Epoch 4/5
# 391/391 [==============================] - 235s 601ms/step - loss: 0.1466 - val_loss: 2.5561
# Epoch 5/5
# 391/391 [==============================] - 265s 678ms/step - loss: 0.1028 - val_loss: 2.5351
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp2mi83y23.h5
# cnn_pruning with final_sparsity: 0.65
# Epoch 1/5
# 391/391 [==============================] - 290s 743ms/step - loss: 0.2577 - val_loss: 2.2869
# Epoch 2/5
# 391/391 [==============================] - 259s 662ms/step - loss: 0.0696 - val_loss: 2.7298
# Epoch 3/5
# 391/391 [==============================] - 241s 617ms/step - loss: 0.0444 - val_loss: 3.5271
# Epoch 4/5
# 391/391 [==============================] - 270s 690ms/step - loss: 0.1617 - val_loss: 2.6284
# Epoch 5/5
# 391/391 [==============================] - 291s 745ms/step - loss: 0.1062 - val_loss: 2.3747
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpmpgj8a7h.h5
# cnn_pruning with final_sparsity: 0.7
# Epoch 1/5
# 391/391 [==============================] - 266s 681ms/step - loss: 0.2530 - val_loss: 2.3276
# Epoch 2/5
# 391/391 [==============================] - 231s 591ms/step - loss: 0.0700 - val_loss: 2.2571
# Epoch 3/5
# 391/391 [==============================] - 245s 626ms/step - loss: 0.0397 - val_loss: 2.8969
# Epoch 4/5
# 391/391 [==============================] - 242s 619ms/step - loss: 0.2793 - val_loss: 1.8708
# Epoch 5/5
# 391/391 [==============================] - 271s 693ms/step - loss: 0.1585 - val_loss: 1.7218
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmput56lb_4.h5
# cnn_pruning with final_sparsity: 0.75
# Epoch 1/5
# 391/391 [==============================] - 287s 733ms/step - loss: 0.2984 - val_loss: 1.6399
# Epoch 2/5
# 391/391 [==============================] - 238s 608ms/step - loss: 0.0770 - val_loss: 1.9175
# Epoch 3/5
# 391/391 [==============================] - 270s 691ms/step - loss: 0.0400 - val_loss: 2.1480
# Epoch 4/5
# 391/391 [==============================] - 271s 692ms/step - loss: 0.1889 - val_loss: 1.5060
# Epoch 5/5
# 391/391 [==============================] - 277s 710ms/step - loss: 0.1887 - val_loss: 1.2602
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmp4sw1fr1p.h5
# cnn_pruning with final_sparsity: 0.8
# Epoch 1/5
# 391/391 [==============================] - 264s 676ms/step - loss: 0.3234 - val_loss: 1.4129
# Epoch 2/5
# 391/391 [==============================] - 228s 583ms/step - loss: 0.0819 - val_loss: 1.6534
# Epoch 3/5
# 391/391 [==============================] - 254s 648ms/step - loss: 0.0441 - val_loss: 1.7311
# Epoch 4/5
# 391/391 [==============================] - 251s 643ms/step - loss: 0.2220 - val_loss: 1.2227
# Epoch 5/5
# 391/391 [==============================] - 288s 736ms/step - loss: 0.2592 - val_loss: 1.0635
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpz9ar0smf.h5
# cnn_pruning with final_sparsity: 0.85
# Epoch 1/5
# 391/391 [==============================] - 271s 694ms/step - loss: 0.3918 - val_loss: 1.3746
# Epoch 2/5
# 391/391 [==============================] - 247s 632ms/step - loss: 0.1096 - val_loss: 1.3493
# Epoch 3/5
# 391/391 [==============================] - 319s 817ms/step - loss: 0.0625 - val_loss: 1.3526
# Epoch 4/5
# 391/391 [==============================] - 290s 741ms/step - loss: 0.3309 - val_loss: 0.9619
# Epoch 5/5
# 391/391 [==============================] - 310s 792ms/step - loss: 0.3927 - val_loss: 0.8776
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpsm5cmhlv.h5
# cnn_pruning with final_sparsity: 0.9
# Epoch 1/5
# 391/391 [==============================] - 244s 623ms/step - loss: 0.4985 - val_loss: 0.8660
# Epoch 2/5
# 391/391 [==============================] - 174s 445ms/step - loss: 0.1830 - val_loss: 1.0528
# Epoch 3/5
# 391/391 [==============================] - 226s 579ms/step - loss: 0.1178 - val_loss: 0.9936
# Epoch 4/5
# 391/391 [==============================] - 224s 573ms/step - loss: 0.4395 - val_loss: 0.8712
# Epoch 5/5
# 391/391 [==============================] - 185s 474ms/step - loss: 0.5684 - val_loss: 0.8057
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpaitdgvkp.h5
# cnn_pruning with final_sparsity: 0.95
# Epoch 1/5
# 391/391 [==============================] - 180s 461ms/step - loss: 0.6947 - val_loss: 0.7787
# Epoch 2/5
# 391/391 [==============================] - 142s 364ms/step - loss: 0.3239 - val_loss: 0.7867
# Epoch 3/5
# 391/391 [==============================] - 140s 358ms/step - loss: 0.2482 - val_loss: 0.7910
# Epoch 4/5
# 391/391 [==============================] - 141s 362ms/step - loss: 0.7368 - val_loss: 1.1797
# Epoch 5/5
# 391/391 [==============================] - 140s 358ms/step - loss: 1.0213 - val_loss: 0.9492
# Pruned model saved: /var/folders/wb/jbgkphrs6hjbdj8nwrl89gg80000gn/T/tmpw7looc5c.h5

# %%
synapse_deletion=np.arange(0.05,1.,0.05)
plt.rcParams['figure.dpi'] = 300
plt.rcParams['savefig.dpi'] = 300

plt.plot(synapse_deletion,err_prun6_list)
plt.plot(synapse_deletion,error6_list)
plt.title("RMSprop, Categorical Cross Entropy Loss as a function of synapse deletion \n $CNN_2$ trained on 50 epochs \n + pruning over 5 epochs \n CIFAR10")
plt.xlabel("Synapse percentage deletion")
plt.ylabel("Categorical Cross Entropy Loss")
plt.show()

# %% [markdown]
# ### Observations: Contrary to Autoencoder, pruning up to 80% of weights does not help performance, but pruning between 80% and 95% of weights helps performance on test data
